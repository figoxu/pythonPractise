# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = (
    Bar()
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子"])
    .add_yaxis("商家A", [5,20,15,2], category_gap="90%",color="#ec0000")
    .add_yaxis("商家B", [20,10,5,13], category_gap="90%",color="#675bba")
    .add_yaxis("商家C", [15,20,5,3], category_gap="90%",color="#000")
    .add_yaxis("商家D", [10,15,5,20], category_gap="50%",color="#f46d43")
    .set_global_opts(title_opts=opts.TitleOpts(title="商品主标题A", subtitle="商品副标题B"))
 
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b9c11c439db74ac6b31ec09e94871071" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b9c11c439db74ac6b31ec09e94871071 = echarts.init(
#                     document.getElementById('b9c11c439db74ac6b31ec09e94871071'), 'white', {renderer: 'canvas'});
#                 var option_b9c11c439db74ac6b31ec09e94871071 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#f46d43",
#         "#000",
#         "#675bba",
#         "#ec0000",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 5,
#                 20,
#                 15,
#                 2
#             ],
#             "barCategoryGap": "90%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 20,
#                 10,
#                 5,
#                 13
#             ],
#             "barCategoryGap": "90%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6C",
#             "data": [
#                 15,
#                 20,
#                 5,
#                 3
#             ],
#             "barCategoryGap": "90%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6D",
#             "data": [
#                 10,
#                 15,
#                 5,
#                 20
#             ],
#             "barCategoryGap": "50%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B",
#                 "\u5546\u5bb6C",
#                 "\u5546\u5bb6D"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true,
#                 "\u5546\u5bb6C": true,
#                 "\u5546\u5bb6D": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u5546\u54c1\u4e3b\u6807\u9898A",
#             "subtext": "\u5546\u54c1\u526f\u6807\u9898B",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b9c11c439db74ac6b31ec09e94871071.setOption(option_b9c11c439db74ac6b31ec09e94871071);
#         });
#     </script>

# %%
import datetime
import random
#导入配置项和基本图表中的日历图
from pyecharts import options as opts
from pyecharts.charts import Calendar

#函数返回日历表
def calendar_base() -> Calendar:
    begin = datetime.date(2017, 1, 1)
    end = datetime.date(2017, 12, 31)
    '''
    此处数据data的形式依据文档中add()方法参数解释说明给定：“”中为引用文档中的说明。
    “# 系列数据，格式为 [(date1, value1), (date2, value2), ...]
     qyaxis_data: Sequence”
    '''
    data = [
        [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
        for i in range((end - begin).days + 1)
    ]

    c = (
        Calendar()#以下方法调用为链式调用
        .add("", data, calendar_opts=opts.CalendarOpts(range_="2017"))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
            visualmap_opts=opts.VisualMapOpts(
                max_=20000,
                min_=500,
                orient="horizontal",
                is_piecewise=True,
                pos_top="230px",
                pos_left="100px",
            ),
        )
    )
    return c
calendar_base().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7389614aa2d947e497485b36023e95b6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7389614aa2d947e497485b36023e95b6 = echarts.init(
#                     document.getElementById('7389614aa2d947e497485b36023e95b6'), 'white', {renderer: 'canvas'});
#                 var option_7389614aa2d947e497485b36023e95b6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2017-01-01",
#                     11186
#                 ],
#                 [
#                     "2017-01-02",
#                     13922
#                 ],
#                 [
#                     "2017-01-03",
#                     15589
#                 ],
#                 [
#                     "2017-01-04",
#                     4896
#                 ],
#                 [
#                     "2017-01-05",
#                     22779
#                 ],
#                 [
#                     "2017-01-06",
#                     3840
#                 ],
#                 [
#                     "2017-01-07",
#                     21155
#                 ],
#                 [
#                     "2017-01-08",
#                     19870
#                 ],
#                 [
#                     "2017-01-09",
#                     20500
#                 ],
#                 [
#                     "2017-01-10",
#                     14416
#                 ],
#                 [
#                     "2017-01-11",
#                     17328
#                 ],
#                 [
#                     "2017-01-12",
#                     19195
#                 ],
#                 [
#                     "2017-01-13",
#                     13948
#                 ],
#                 [
#                     "2017-01-14",
#                     7893
#                 ],
#                 [
#                     "2017-01-15",
#                     18059
#                 ],
#                 [
#                     "2017-01-16",
#                     6076
#                 ],
#                 [
#                     "2017-01-17",
#                     2932
#                 ],
#                 [
#                     "2017-01-18",
#                     21137
#                 ],
#                 [
#                     "2017-01-19",
#                     13155
#                 ],
#                 [
#                     "2017-01-20",
#                     4035
#                 ],
#                 [
#                     "2017-01-21",
#                     23984
#                 ],
#                 [
#                     "2017-01-22",
#                     14127
#                 ],
#                 [
#                     "2017-01-23",
#                     7468
#                 ],
#                 [
#                     "2017-01-24",
#                     8875
#                 ],
#                 [
#                     "2017-01-25",
#                     7986
#                 ],
#                 [
#                     "2017-01-26",
#                     18859
#                 ],
#                 [
#                     "2017-01-27",
#                     10626
#                 ],
#                 [
#                     "2017-01-28",
#                     15487
#                 ],
#                 [
#                     "2017-01-29",
#                     3571
#                 ],
#                 [
#                     "2017-01-30",
#                     5834
#                 ],
#                 [
#                     "2017-01-31",
#                     18270
#                 ],
#                 [
#                     "2017-02-01",
#                     8056
#                 ],
#                 [
#                     "2017-02-02",
#                     21994
#                 ],
#                 [
#                     "2017-02-03",
#                     1806
#                 ],
#                 [
#                     "2017-02-04",
#                     7818
#                 ],
#                 [
#                     "2017-02-05",
#                     14281
#                 ],
#                 [
#                     "2017-02-06",
#                     21227
#                 ],
#                 [
#                     "2017-02-07",
#                     3495
#                 ],
#                 [
#                     "2017-02-08",
#                     11422
#                 ],
#                 [
#                     "2017-02-09",
#                     3836
#                 ],
#                 [
#                     "2017-02-10",
#                     1544
#                 ],
#                 [
#                     "2017-02-11",
#                     1145
#                 ],
#                 [
#                     "2017-02-12",
#                     22858
#                 ],
#                 [
#                     "2017-02-13",
#                     11257
#                 ],
#                 [
#                     "2017-02-14",
#                     18815
#                 ],
#                 [
#                     "2017-02-15",
#                     16997
#                 ],
#                 [
#                     "2017-02-16",
#                     6438
#                 ],
#                 [
#                     "2017-02-17",
#                     22593
#                 ],
#                 [
#                     "2017-02-18",
#                     11010
#                 ],
#                 [
#                     "2017-02-19",
#                     19474
#                 ],
#                 [
#                     "2017-02-20",
#                     17566
#                 ],
#                 [
#                     "2017-02-21",
#                     4629
#                 ],
#                 [
#                     "2017-02-22",
#                     20628
#                 ],
#                 [
#                     "2017-02-23",
#                     5050
#                 ],
#                 [
#                     "2017-02-24",
#                     15257
#                 ],
#                 [
#                     "2017-02-25",
#                     19604
#                 ],
#                 [
#                     "2017-02-26",
#                     15156
#                 ],
#                 [
#                     "2017-02-27",
#                     11489
#                 ],
#                 [
#                     "2017-02-28",
#                     16323
#                 ],
#                 [
#                     "2017-03-01",
#                     17638
#                 ],
#                 [
#                     "2017-03-02",
#                     19506
#                 ],
#                 [
#                     "2017-03-03",
#                     14933
#                 ],
#                 [
#                     "2017-03-04",
#                     3077
#                 ],
#                 [
#                     "2017-03-05",
#                     24526
#                 ],
#                 [
#                     "2017-03-06",
#                     24105
#                 ],
#                 [
#                     "2017-03-07",
#                     20917
#                 ],
#                 [
#                     "2017-03-08",
#                     20468
#                 ],
#                 [
#                     "2017-03-09",
#                     5839
#                 ],
#                 [

# %%
# http://gallery.pyecharts.org/#/Pie/pie_set_color
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    .add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_colors(["blue", "green", "yellow", "red", "pink", "orange", "purple"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-设置颜色"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6935f97f979d48b3bc58510a2761ee71" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6935f97f979d48b3bc58510a2761ee71 = echarts.init(
#                     document.getElementById('6935f97f979d48b3bc58510a2761ee71'), 'white', {renderer: 'canvas'});
#                 var option_6935f97f979d48b3bc58510a2761ee71 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "green",
#         "yellow",
#         "red",
#         "pink",
#         "orange",
#         "purple"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 81
#                 },
#                 {
#                     "name": "\u6bdb\u8863",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u9886\u5e26",
#                     "value": 106
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 38
#                 },
#                 {
#                     "name": "\u98ce\u8863",
#                     "value": 134
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 149
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 42
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u8bbe\u7f6e\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_6935f97f979d48b3bc58510a2761ee71.setOption(option_6935f97f979d48b3bc58510a2761ee71);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie

c = (
    Pie()
    .add_dataset(
        source=[
            ["product", "2012", "2013", "2014", "2015", "2016", "2017"],
            ["Matcha Latte", 41.1, 30.4, 65.1, 53.3, 83.8, 98.7],
            ["Milk Tea", 86.5, 92.1, 85.7, 83.1, 73.4, 55.1],
            ["Cheese Cocoa", 24.1, 67.2, 79.5, 86.4, 65.2, 82.5],
            ["Walnut Brownie", 55.2, 67.1, 69.2, 72.4, 53.9, 39.1],
        ]
    )
    .add(
        series_name="Matcha Latte",
        data_pair=[],
        radius=60,
        center=["25%", "30%"],
        encode={"itemName": "product", "value": "2012"},
    )
    .add(
        series_name="Milk Tea",
        data_pair=[],
        radius=60,
        center=["75%", "30%"],
        encode={"itemName": "product", "value": "2013"},
    )
    .add(
        series_name="Cheese Cocoa",
        data_pair=[],
        radius=60,
        center=["25%", "75%"],
        encode={"itemName": "product", "value": "2014"},
    )
    .add(
        series_name="Walnut Brownie",
        data_pair=[],
        radius=60,
        center=["75%", "75%"],
        encode={"itemName": "product", "value": "2015"},
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Dataset simple pie example"),
        legend_opts=opts.LegendOpts(pos_left="30%", pos_top="2%"),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fb76419bbad243b789ee8d99ffc3fc3b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fb76419bbad243b789ee8d99ffc3fc3b = echarts.init(
#                     document.getElementById('fb76419bbad243b789ee8d99ffc3fc3b'), 'white', {renderer: 'canvas'});
#                 var option_fb76419bbad243b789ee8d99ffc3fc3b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "Matcha Latte",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "25%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2012"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Milk Tea",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "75%",
#                 "30%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2013"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Cheese Cocoa",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "25%",
#                 "75%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2014"
#             }
#         },
#         {
#             "type": "pie",
#             "name": "Walnut Brownie",
#             "clockwise": true,
#             "radius": 60,
#             "center": [
#                 "75%",
#                 "75%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "encode": {
#                 "itemName": "product",
#                 "value": "2015"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Matcha Latte",
#                 "Milk Tea",
#                 "Cheese Cocoa",
#                 "Walnut Brownie"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "30%",
#             "top": "2%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "dataset": {
#         "source": [
#             [
#                 "product",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017"
#             ],
#             [
#                 "Matcha Latte",
#                 41.1,
#                 30.4,
#                 65.1,
#                 53.3,
#                 83.8,
#                 98.7
#             ],
#             [
#                 "Milk Tea",
#                 86.5,
#                 92.1,
#                 85.7,
#                 83.1,
#                 73.4,
#                 55.1
#             ],
#             [
#                 "Cheese Cocoa",
#                 24.1,
#                 67.2,
#                 79.5,
#                 86.4,
#                 65.2,
#                 82.5
#             ],
#             [
#                 "Walnut Brownie",
#                 55.2,
#                 67.1,
#                 69.2,
#                 72.4,
#                 53.9,
#                 39.1
#             ]
#         ]
#     },
#     "title": [
#         {
#             "text": "Dataset simple pie example",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_fb76419bbad243b789ee8d99ffc3fc3b.setOption(option_fb76419bbad243b789ee8d99ffc3fc3b);
#         });
#     </script>
